# %% [markdown]
# # Actividad Evaluable: Mapas de calor y boxplots
#
# ## 1. Carga los datos usando tu lector de csv o con pandas. Es recomendable hacerlo con pandas.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Charging data
df = pd.read_csv('TC1002S/covid19_tweets.csv')

# Converting boolean columns to int
df['user_verified'] = df['user_verified'].astype(int)
df['is_retweet'] = df['is_retweet'].astype(int)

# Displaying the first 5 rows
df.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775              0
# 1            2253          1677               24              1
# 2            9275          9525             7254              0
# ...

# %% [markdown]
# ## 2. Realiza el análisis de las variables usando diagramas de cajas y bigotes, histogramas y mapas de calor.

# %% [markdown]
# ### Diagramas de cajas y bigotes, así como histogramas

# %% [markdown]
# ### user_followers

# %%
# Box plot of user_followers
sns.boxplot(data=df['user_followers'], showfliers=False)
# Out:
# <Axes: >

# %%
# Histogram of user_followers
fig, ax = plt.subplots()
ax.hist(df['user_followers'])
plt.show()

# %% [markdown]
# ### user_friends

# %%
# Box plot of user_friends
sns.boxplot(data=df['user_friends'], showfliers=False)
# Out:
# <Axes: >

# %%
# Histogram of user_friends
fig, ax = plt.subplots()
ax.hist(df['user_friends'])
plt.show()

# %% [markdown]
# ### user_favourites

# %%
# Box plot of user_favourites
sns.boxplot(data=df['user_favourites'], showfliers=False)
# Out:
# <Axes: >

# %%
# Histogram of user_favourites
fig, ax = plt.subplots()
ax.hist(df['user_favourites'])
plt.show()

# %% [markdown]
# ### user_verified

# %%
# Box plot of user_verified
sns.boxplot(data=df['user_verified'], showfliers=False)
# Out:
# <Axes: >

# %%
# Histogram of user_verified
fig, ax = plt.subplots()
ax.hist(df['user_verified'])
plt.show()

# %% [markdown]
# ### is_retweet

# %%
# Box plot of is_retweet
sns.boxplot(data=df['is_retweet'], showfliers=False)
# Out:
# <Axes: >

# %%
# Histogram of is_retweet
fig, ax = plt.subplots()
ax.hist(df['is_retweet'])
plt.show()

# %%
df.corr()
# Out:
# /var/folders/44/0pfv53sn2hs3ghwtq8p2d6lc0000gn/T/ipykernel_11308/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                  user_followers  user_friends  user_favourites  user_verified  \
# user_followers         1.000000     -0.002722        -0.028724       0.322896
# user_friends          -0.002722      1.000000         0.207825       0.013099
# user_favourites       -0.028724      0.207825         1.000000      -0.060316
# user_verified          0.322896      0.013099        -0.060316       1.000000
# is_retweet                  NaN           NaN              NaN            NaN
#
#                  is_retweet
# user_followers          NaN
# user_friends            NaN
# user_favourites         NaN
# user_verified           NaN
# is_retweet              NaN

# %%
# Heatmap
sns.heatmap(df.corr());
# Out:
# /var/folders/44/0pfv53sn2hs3ghwtq8p2d6lc0000gn/T/ipykernel_11308/4023343526.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr());

# %% [markdown]
# ## Responde las siguientes preguntas:
#
# ¿Hay alguna variable que no aporta información?
# Si, hasta este punto, no aportan información todas las variables que no son numéricas, sin embargo podríamos explorar las variables no numéricas al transformarlas a numéricas
#
# Si tuvieras que eliminar variables, ¿Cuáles quitarías y por qué?
# Hasta ahorita user location and user name, ya que no aportan información relevante para el análisis, debido a que son texto que requeriría un análisis de lenguaje natural para poder ver si aportan algo.
#
# ¿Existen variables que tengan datos extraños?
# Si, al parecer la variable user_location no es una variable que extrajera información a través de geolocalización, sino es una variable con texto abierto al usuario, por lo cuál las respuestas son disparatadas y no aportan información relevante.
#
# Si comparas las variables, ¿todas están en rangos similares? ¿Crees que esto afecte?
# No están en rangos similares, sin embargo no creo que afecten por esta situación, ya que lo que realmente afecta es que no haya correlación entre las variables.
#
# ¿Puedes encontrar grupos qué se parezcan? ¿Qué grupos son estos?
# Si, los grupos que se parecen y podemos observar a través del mapa de calor son lo grupos de user_followers e is_retweet, así como user_friends y user_favourites.
